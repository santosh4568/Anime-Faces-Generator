# %% [markdown]
# <a href="https://colab.research.google.com/github/santosh4568/Anime-Faces-Generator/blob/main/Training_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import warnings
from tqdm.notebook import tqdm

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img , array_to_img
from tensorflow.keras.models import Sequential , Model
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy

# %%
warnings.filterwarnings('ignore')

# %%
Base_dir = "/content/drive/MyDrive/Datasets/data"

# %%
image_paths = []
for image_name in os.listdir(Base_dir):
    image_path = os.path.join(Base_dir, image_name)
    image_paths.append(image_path)

# %%
image_paths[:10]
# Out:
# ['/content/drive/MyDrive/Datasets/data/16668.png',
#  '/content/drive/MyDrive/Datasets/data/16396.png',
#  '/content/drive/MyDrive/Datasets/data/16800.png',
#  '/content/drive/MyDrive/Datasets/data/16852.png',
#  '/content/drive/MyDrive/Datasets/data/16047.png',
#  '/content/drive/MyDrive/Datasets/data/16153.png',
#  '/content/drive/MyDrive/Datasets/data/15903.png',
#  '/content/drive/MyDrive/Datasets/data/16707.png',
#  '/content/drive/MyDrive/Datasets/data/16468.png',
#  '/content/drive/MyDrive/Datasets/data/16299.png']

# %%
len(image_paths)
# Out:
# 8631

# %%
plt.figure(figsize=(20, 20))
temp_images = image_paths[:49]
index = 1

for image_path in temp_images:
    plt.subplot(7, 7, index)
    # load the image
    img = load_img(image_path)
    # convert to numpy array
    img = np.array(img)
    # show the image
    plt.imshow(img)
    plt.axis('off')
    # increment the index for next image
    index += 1

# %%
train_images = [np.array(load_img(path)) for path in tqdm(image_paths)]
train_images = np.array(train_images)
# Out:
#   0%|          | 0/8631 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-2b083abd974c> in <cell line: 1>()
# ----> 1 train_images = [np.array(load_img(path)) for path in tqdm(image_paths)]
#       2 train_images = np.array(train_images)
#
# <ipython-input-14-2b083abd974c> in <listcomp>(.0)
# ----> 1 train_images = [np.array(load_img(path)) for path in tqdm(image_paths)]
#       2 train_images = np.array(train_images)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     421             path = str(path.resolve())
#     422         with open(path, "rb") as f:
# --> 423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#     425         raise TypeError(
#
# KeyboardInterrupt:
